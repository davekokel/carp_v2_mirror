# %%
# legacy_linking_v7 — CELL L1: Setup and load raw Excel inputs

import pandas as pd
from pathlib import Path

BASE    = Path("/Users/davekokel/Projects/carp_v2")
RAW     = BASE / "seed_kits" / "legacy_wrangling" / "raw"
WORKING = BASE / "seed_kits" / "legacy_wrangling" / "working"

roi_paths_path     = RAW / "2025-11-13-092338-korra_aang_roi_root_tiffs_good-3.xlsx"
imaging_sheet_path = RAW / "2025-11-13-124226-imaging_sheet.xlsx"

# Raw ROI paths
df_roi_paths = pd.read_excel(roi_paths_path)

# Imaging sheet is a single worksheet with ROI + mount/metadata
df_imaging = pd.read_excel(imaging_sheet_path)

# %%
# CELL L2 — standardize ROI paths

df_roi_paths["roi_dir"]  = df_roi_paths["roi_dir"].astype(str).str.strip()
df_roi_paths["roi_name"] = df_roi_paths["roi_name"].astype(str).str.strip()
ROI_KEY = "roi_dir"

# %%
# CELL L3 — mount_dir_norm in both tables + merge on mount_dir_norm

import re

def norm_path(p: str) -> str:
    if p is None or (isinstance(p, float) and pd.isna(p)):
        return None
    s = str(p).replace("\\", "/")
    s = re.sub(r"^[A-Za-z]:", "", s)          # strip X: drive
    s = s.replace("/clusterfs/vast", "")
    s = s.replace("/clusterfs/nvme", "")
    s = s.replace("/clusterfs/nvme2", "")
    s = re.sub(r"/+", "/", s)
    return s.rstrip("/")

# imaging: mount-level path
df_imaging["mount_dir_norm"] = df_imaging["Data location"].apply(norm_path)

# ROI: mount-dir = roi_dir without the last segment
def roi_mount_dir(path: str) -> str:
    s = norm_path(path)
    if s is None:
        return None
    parts = s.split("/")
    if len(parts) <= 1:
        return s
    # drop last segment (roiX_...)
    return "/".join(parts[:-1])

df_roi_paths["mount_dir_norm"] = df_roi_paths["roi_dir"].apply(roi_mount_dir)

df_roi_paths[["roi_dir","mount_dir_norm"]].head()
df_imaging[["Data location","mount_dir_norm","ZF female genotype","ZF male genotype"]].head()
# Out:
#                                      Data location  \
# 0     X:\abcabc\Korra_Foundation\20251112_mem-mito
# 1   X:\abcabc\Exploratory_fish\20251112_mem-moesin
# 2      X:\abcabc\Aang_Foundation\20251107_mem-mito
# 3  X:\abcabc\Korra_Foundation\20251110_mem-histone
# 4      X:\abcabc\Aang_Foundation\20251106_mem-mito
#
#                                   mount_dir_norm  \
# 0     /abcabc/Korra_Foundation/20251112_mem-mito
# 1   /abcabc/Exploratory_fish/20251112_mem-moesin
# 2      /abcabc/Aang_Foundation/20251107_mem-mito
# 3  /abcabc/Korra_Foundation/20251110_mem-histone
# 4      /abcabc/Aang_Foundation/20251106_mem-mito
#
#                         ZF female genotype  \
# 0                                   casper
# 1                                   casper
# 2                                   casper
# 3  ef1a:2xLynk:tdmSG(J) (F1 of allele 301)
# 4                                   casper
#
#                             ZF male genotype
# ...

# %%
# CELL L4 — merge ROI paths with imaging on mount_dir_norm
df_linked = df_roi_paths.merge(
    df_imaging,
    on="mount_dir_norm",
    how="left",
    suffixes=("", "_im"),
)

df_linked[[
    "roi_dir",
    "mount_dir_norm",
    "ZF female genotype",
    "ZF male genotype",
    "Data location"
]].head(20)
# Out:
#                                               roi_dir  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# ...

# %%
# CELL L5: Normalize parents

def norm_text(val):
    if val is None or (isinstance(val, float) and pd.isna(val)):
        return None
    s = str(val).strip()
    return s or None

df_linked["parent_female"] = df_linked["ZF female genotype"].apply(norm_text)
df_linked["parent_male"]   = df_linked["ZF male genotype"].apply(norm_text)

df_linked[["roi_dir","parent_female","parent_male"]].head(20)
# Out:
#                                               roi_dir  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# ...

# %%
# CELL L7: Write structural ROI table (v7)

out_path = WORKING / "legacy_roi_structural_v2_mount_linked.csv"
df_linked.to_csv(out_path, index=False)
out_path, df_linked.shape
# Out:
# (PosixPath('/Users/davekokel/Projects/carp_v2/seed_kits/legacy_wrangling/working/legacy_roi_structural_v2_mount_linked.csv'),
#  (1077, 30))

# %%
import pandas as pd
from pathlib import Path

BASE    = Path("/Users/davekokel/Projects/carp_v2")
WORKING = BASE / "seed_kits" / "legacy_wrangling" / "working"

struct_path = WORKING / "legacy_roi_structural_v7.csv"
sdf = pd.read_csv(struct_path)

sdf.loc[
    sdf["experiment_slug"] == "Korra_Foundation/20250428_mem_histone",
    ["roi_dir","experiment_slug","parent_female","parent_male"]
].head(10)
# Out:
#                                              roi_dir  \
# 0  /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 1  /clusterfs/vast/abcabc/Korra_Foundation/202504...
#
#                          experiment_slug  \
# 0  Korra_Foundation/20250428_mem_histone
# 1  Korra_Foundation/20250428_mem_histone
#
#                              parent_female  \
# 0  ef1a:2xLynk:tdmSG(J) (F2 of allele 301)
# 1  ef1a:2xLynk:tdmSG(J) (F2 of allele 301)
#
#                                parent_male
# 0  ef1a:2xLynk:tdmSG(J) (F2 of allele 301)
# 1  ef1a:2xLynk:tdmSG(J) (F2 of allele 301)

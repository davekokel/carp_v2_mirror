# %%
# LINKING_V4 — L1: load raw ROI paths + imaging sheet

from pathlib import Path
import pandas as pd

ROOT = Path("/Users/davekokel/Projects/carp_v2")
if not ROOT.exists():
    raise FileNotFoundError(f"Expected repo root at {ROOT}, but it does not exist.")

BASE    = ROOT / "seed_kits" / "legacy_wrangling_v2"
RAW     = BASE / "raw"
WORKING = BASE / "working"

for p in [RAW, WORKING]:
    if not p.exists():
        raise FileNotFoundError(f"Expected directory at {p}, but it does not exist.")

ROI_PATHS_FILE   = RAW / "2025-11-13-092338-korra_aang_roi_root_tiffs_good-3.xlsx"
IMAGING_SHEET_FILE = RAW / "2025-11-13-124226-imaging_sheet.xlsx"

print("ROI paths file:     ", ROI_PATHS_FILE)
print("Imaging sheet file: ", IMAGING_SHEET_FILE)

df_roi_paths = pd.read_excel(ROI_PATHS_FILE)
df_imaging   = pd.read_excel(IMAGING_SHEET_FILE)

print("df_roi_paths shape:", df_roi_paths.shape)
print("df_imaging shape: ", df_imaging.shape)
print("df_roi_paths columns:", list(df_roi_paths.columns))
print("df_imaging columns:", list(df_imaging.columns))
# Out:
# ROI paths file:      /Users/davekokel/Projects/carp_v2/seed_kits/legacy_wrangling_v2/raw/2025-11-13-092338-korra_aang_roi_root_tiffs_good-3.xlsx
# Imaging sheet file:  /Users/davekokel/Projects/carp_v2/seed_kits/legacy_wrangling_v2/raw/2025-11-13-124226-imaging_sheet.xlsx
# df_roi_paths shape: (976, 7)
# df_imaging shape:  (307, 20)
# df_roi_paths columns: ['date_experiment', 'fish', 'roi_rel', 'roi_name', 'roi_tiffs', 'roi_dir', 'dataset']
# df_imaging columns: ['date_mount', 'mount_id', 'ZF female genotype', 'ZF male genotype', 'additional plasmids injected', 'additional mRNAs injected', 'additonal proteins injected', 'additonal dye and chemicals', 'Date born', 'Time mounted', 'Mounting Orientation', 'Date screened/Initial feedback', 'Date imaged', 'Time placed in scope', 'Start of imaging time', 'End of imaging time', 'Imaged Locations', 'Unique Targets with blanks', 'Unique Targets', 'Data location']

# %%
# LINKING_V4 — L2: standardize ROI paths (roi_dir / roi_name)

# Expect df_roi_paths columns to include:
#   'roi_dir', 'roi_name', 'roi_tiffs', 'fish', 'date_experiment', etc.

if "roi_dir" not in df_roi_paths.columns:
    raise KeyError("df_roi_paths is missing 'roi_dir' column.")
if "roi_name" not in df_roi_paths.columns:
    raise KeyError("df_roi_paths is missing 'roi_name' column.")

df_roi_paths = df_roi_paths.copy()

df_roi_paths["roi_dir"] = (
    df_roi_paths["roi_dir"]
    .astype(str)
    .str.strip()
    .str.replace("\\", "/", regex=False)
)

df_roi_paths["roi_name"] = (
    df_roi_paths["roi_name"]
    .astype(str)
    .str.strip()
)

print("L2: sample standardized ROI rows:")
print(df_roi_paths[["roi_dir", "roi_name"]].head(20))
# Out:
# L2: sample standardized ROI rows:
#                                               roi_dir              roi_name
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...             roi1_tail
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...  roi2_hindbrain_spine
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi1
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...             roi1_test
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi1
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi1
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi2
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi1
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi2
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...                  roi3
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi1
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi2
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...                roi2_2
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi1
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi1
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...             roi1_test
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi1
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi2
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi3
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...                  roi1

# %%
# LINKING_V4 — L2a: extract roi_path_date_yyyymmdd from roi_dir

import re
import math

def extract_roi_path_date(path):
    """
    Extract YYYYMMDD from ROI path segments like:
      .../20250428_mem_histone/fish1_72hpf/roi1_tail
      .../20250627_skittlez/fishX/roiY

    Rule:
      Find a path component that matches ^\d{8}_.+ and return the 8-digit prefix.
    """
    if path is None or (isinstance(path, float) and pd.isna(path)):
        return None

    s = str(path)
    parts = s.split("/")
    for p in parts:
        m = re.match(r"^(\d{8})_.+", p)
        if m:
            return m.group(1)
    return None

df_roi_paths["roi_path_date_yyyymmdd"] = df_roi_paths["roi_dir"].apply(extract_roi_path_date)

n_total   = len(df_roi_paths)
n_nonnull = df_roi_paths["roi_path_date_yyyymmdd"].notna().sum()
n_null    = n_total - n_nonnull
n_unique  = df_roi_paths["roi_path_date_yyyymmdd"].nunique()

print("L2a — ROI path date extraction QC")
print("  total rows:           ", n_total)
print("  non-null dates:       ", n_nonnull)
print("  null dates:           ", n_null)
print("  unique dates:         ", n_unique)

if n_null > 0:
    print("\nL2a: sample rows with NULL roi_path_date_yyyymmdd:")
    print(df_roi_paths[df_roi_paths["roi_path_date_yyyymmdd"].isna()][["roi_dir"]].head(20))

print("\nL2a: sample ROI rows with parsed dates:")
print(df_roi_paths[["roi_dir", "roi_path_date_yyyymmdd"]].head(20))
# Out:
# L2a — ROI path date extraction QC
#   total rows:            976
#   non-null dates:        975
#   null dates:            1
#   unique dates:          76
#
# L2a: sample rows with NULL roi_path_date_yyyymmdd:
#                                                roi_dir
# 419  /clusterfs/vast/abcabc/Korra_Foundation/analys...
#
# L2a: sample ROI rows with parsed dates:
#                                               roi_dir roi_path_date_yyyymmdd
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250428
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250428
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/29/cdrb2nrn01s4d1_n6gvxy5j80000gn/T/ipykernel_45674/1009012992.py:13: SyntaxWarning: invalid escape sequence '\d'
#   Find a path component that matches ^\d{8}_.+ and return the 8-digit prefix.

# %%
# LINKING_V4 — L2b: drop ROI rows that do not contain a parsable experiment date

mask_valid = df_roi_paths["roi_path_date_yyyymmdd"].notna()

n_total = len(df_roi_paths)
n_keep  = mask_valid.sum()
n_drop  = n_total - n_keep

print("L2b — filter non-experiment ROIs")
print("  total ROI rows:", n_total)
print("  keeping       :", n_keep)
print("  dropping      :", n_drop)

if n_drop > 0:
    print("\nL2b: sample of dropped roi_dir values:")
    print(df_roi_paths.loc[~mask_valid, ["roi_dir"]].head(20))

df_roi_paths = df_roi_paths.loc[mask_valid].reset_index(drop=True)

print("\nL2b: df_roi_paths shape after filter:", df_roi_paths.shape)
# Out:
# L2b — filter non-experiment ROIs
#   total ROI rows: 976
#   keeping       : 975
#   dropping      : 1
#
# L2b: sample of dropped roi_dir values:
#                                                roi_dir
# 419  /clusterfs/vast/abcabc/Korra_Foundation/analys...
#
# L2b: df_roi_paths shape after filter: (975, 8)

# %%
# LINKING_V4 — L2c: extract experiment_folder, fish_folder, roi_folder, fish_id (robust)

import re
import pandas as pd

# --- helpers to pull pieces out of roi_dir -----------------------------------

def extract_experiment_folder(path: str) -> str:
    """
    From roi_dir like:
      .../20250428_mem_histone/fish1_72hpf/roi1_tail
      .../20250606_skittlez/fish10_roi1
    pick the experiment folder:
      -> 20250428_mem_histone
      -> 20250606_skittlez
    """
    parts = str(path).split("/")
    for p in parts:
        if re.match(r"\d{8}_.+", p):
            return p
    return None

def extract_fish_folder(path: str) -> str:
    """
    FISH folder is the directory immediately under experiment_folder.
    For korra skittlez data this can be:
      - 'fish1_72hpf'
      - 'fish3_mem-halo_24hpf'
      - 'fish10_roi1'
    """
    parts = str(path).split("/")
    for i, p in enumerate(parts):
        if re.match(r"\d{8}_.+", p) and i + 1 < len(parts):
            return parts[i + 1]
    return None

def extract_roi_folder(path: str) -> str:
    """
    ROI folder is the last component of the path.
    For multi-level paths:
      .../fish1_24hpf/roi1_tail  -> 'roi1_tail'
    For one-level fish/ROI combos:
      .../20250606_skittlez/fish10_roi1 -> 'fish10_roi1'
    """
    return str(path).rstrip("/").split("/")[-1]

# --- fish_id extraction: prefer 'fish' column; fallback to generic regex -----

def extract_fish_id_from_fish_col(val):
    """
    Normalize from the 'fish' column in the ROI sheet, if present.

    Examples:
      'fish1'      -> 'fish1'
      'fish 1'     -> 'fish1'
      'Fish 03'    -> 'fish3'
      '3'          -> 'fish3'
      anything else: returned lowercased string
    """
    if val is None:
        return None
    s = str(val).strip().lower()

    # explicit 'fish<digits>' somewhere
    m = re.search(r"fish\s*0*([0-9]+)", s)
    if m:
        return f"fish{int(m.group(1))}"

    # bare digits: treat as fishN
    m = re.fullmatch(r"0*([0-9]+)", s)
    if m:
        return f"fish{int(m.group(1))}"

    return s or None

def extract_fish_id_generic(row: pd.Series) -> str:
    """
    Robust fish_id extractor.

    Priority:
      1) Use df_roi_paths['fish'] if present and parse it.
      2) Look for 'fish<digits>' in fish_folder.
      3) Look for 'fish<digits>' in roi_dir.
      4) Fallback: fish_folder as-is (should be rare).
    """
    # 1) 'fish' column if present
    if "fish" in row and pd.notna(row["fish"]):
        fid = extract_fish_id_from_fish_col(row["fish"])
        if fid is not None:
            return fid

    # 2) fish_folder
    ff = row.get("fish_folder")
    if ff is not None:
        m = re.search(r"fish\s*0*([0-9]+)", str(ff).lower())
        if m:
            return f"fish{int(m.group(1))}"

    # 3) roi_dir
    rd = row.get("roi_dir")
    if rd is not None:
        m = re.search(r"fish\s*0*([0-9]+)", str(rd).lower())
        if m:
            return f"fish{int(m.group(1))}"

    # 4) last resort: use fish_folder verbatim
    return ff if ff is not None else None

# --- apply all of the above to df_roi_paths ----------------------------------

df_roi_paths = df_roi_paths.copy()

df_roi_paths["experiment_folder"] = df_roi_paths["roi_dir"].apply(extract_experiment_folder)
df_roi_paths["fish_folder"]       = df_roi_paths["roi_dir"].apply(extract_fish_folder)
df_roi_paths["roi_folder"]        = df_roi_paths["roi_dir"].apply(extract_roi_folder)
df_roi_paths["fish_id"]           = df_roi_paths.apply(extract_fish_id_generic, axis=1)

print("L2c: sample hierarchy fields from ROI paths (robust fish_id):")
print(
    df_roi_paths[
        ["roi_dir", "roi_path_date_yyyymmdd", "experiment_folder",
         "fish_folder", "fish_id", "roi_folder"]
    ].head(40)
)

print("\nL2c: distinct fish_folder -> fish_id mappings (first 40):")
print(
    df_roi_paths[["fish_folder", "fish_id"]]
      .drop_duplicates()
      .head(40)
)
# Out:
# L2c: sample hierarchy fields from ROI paths:
#                                               roi_dir roi_path_date_yyyymmdd  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250428
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250428
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...               20250429
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 20  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 21  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 22  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 23  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 24  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 25  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 26  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 27  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 28  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
# 29  /clusterfs/vast/abcabc/Korra_Foundation/202505...               20250513
#
#        experiment_folder           fish_folder               fish_id  \
# 0   20250428_mem_histone           fish1_72hpf           fish1_72hpf
# 1   20250428_mem_histone           fish1_72hpf           fish1_72hpf
# 2   20250429_mem_cytosol           fish1_24hpf           fish1_24hpf
# 3   20250429_mem_cytosol           fish1_24hpf           fish1_24hpf
# 4   20250429_mem_cytosol           fish2_48hpf           fish2_48hpf
# 5   20250429_mem_cytosol  fish3_mem-halo_24hpf  fish3_mem-halo_24hpf
# 6   20250429_mem_cytosol  fish3_mem-halo_24hpf  fish3_mem-halo_24hpf
# 7   20250429_mem_cytosol  fish4_mem-halo_48hpf  fish4_mem-halo_48hpf
# 8   20250429_mem_cytosol  fish4_mem-halo_48hpf  fish4_mem-halo_48hpf
# 9   20250429_mem_cytosol  fish4_mem-halo_48hpf  fish4_mem-halo_48hpf
# 10     20250513_skittles                 fish1                 fish1
# 11     20250513_skittles                 fish1                 fish1
# 12     20250513_skittles                 fish1                 fish1
# 13     20250513_skittles                fish10                fish10
# 14     20250513_skittles                fish11                fish11
# 15     20250513_skittles                fish11                fish11
# 16     20250513_skittles                fish12                fish12
# 17     20250513_skittles                fish12                fish12
# 18     20250513_skittles                fish12                fish12
# 19     20250513_skittles                fish13                fish13
# 20     20250513_skittles                fish13                fish13
# 21     20250513_skittles                fish13                fish13
# 22     20250513_skittles                fish13                fish13
# 23     20250513_skittles                fish14                fish14
# 24     20250513_skittles                fish14                fish14
# 25     20250513_skittles                fish15                fish15
# 26     20250513_skittles                fish15                fish15
# 27     20250513_skittles                fish15                fish15
# 28     20250513_skittles                fish15                fish15
# 29     20250513_skittles                fish16                fish16
#
#               roi_folder
# 0              roi1_tail
# 1   roi2_hindbrain_spine
# 2                   roi1
# 3              roi1_test
# 4                   roi1
# 5                   roi1
# 6                   roi2
# 7                   roi1
# 8                   roi2
# 9                   roi3
# 10                  roi1
# 11                  roi2
# 12                roi2_2
# 13                  roi1
# 14                  roi1
# 15             roi1_test
# 16                  roi1
# 17                  roi2
# 18                  roi3
# 19                  roi1
# 20                  roi2
# 21                  roi3
# 22                  roi4
# 23            roi1_brain
# 24          roi2_tailbud
# 25                  roi1
# 26                  roi2
# 27                  roi3
# 28                  roi4
# 29            roi1_brain

# %%
# LINKING_V4 — L3: prepare imaging sheet (imaging_date_from_sheet + dataset_slug)

import pandas as pd
import re
import math

if "Date imaged" not in df_imaging.columns:
    raise KeyError("'Date imaged' column not found in df_imaging.")
if "Data location" not in df_imaging.columns:
    raise KeyError("'Data location' column not found in df_imaging.")

def extract_dataset_slugs_from_dataloc(path):
    """
    From Data location like:
      X:\\abcabc\\Korra_Foundation\\20250627_skittlez and 20250625_skittlez

    extract ALL path-like tokens that look like 'YYYYMMDD_<something>'.

    Returns:
      list of candidates (possibly empty).
    """
    if path is None or (isinstance(path, float) and pd.isna(path)):
        return []
    s = str(path).replace("\\", "/")
    # split on slashes and whitespace and commas and 'and'
    tokens = re.split(r"[\/\s,]+", s)
    cands = []
    for t in tokens:
        m = re.match(r"(\d{8}_.+)", t)
        if m:
            # strip trailing '(...)' if present
            slug = re.sub(r"\(.*\)$", "", m.group(1)).strip()
            cands.append(slug)
    return cands

df_imaging = df_imaging.copy()

# imaging_date_from_sheet = Date imaged as YYYYMMDD
df_imaging["imaging_date_from_sheet"] = pd.to_datetime(
    df_imaging["Date imaged"], errors="coerce"
).dt.strftime("%Y%m%d")

# ALL slug candidates per row
df_imaging["slug_candidates"] = df_imaging["Data location"].apply(extract_dataset_slugs_from_dataloc)

def pick_dataset_slug(row):
    """
    Choose a single dataset_slug from slug_candidates using imaging_date_from_sheet:

      - If no candidates: return None.
      - If exactly one candidate: return it.
      - If multiple candidates:
           Try to keep those whose 8-digit prefix matches imaging_date_from_sheet.
           If exactly one such candidate: return it.
           Else: return None and let QC handle it.
    """
    cands = row["slug_candidates"]
    if not cands:
        return None

    if len(cands) == 1:
        return cands[0]

    img_date = row["imaging_date_from_sheet"]
    if img_date is None or isinstance(img_date, float) and math.isnan(img_date):
        # can't resolve tie without a date; treat as ambiguous
        return None

    # filter candidates by date prefix
    matched = [c for c in cands if c.startswith(img_date + "_")]
    if len(matched) == 1:
        return matched[0]

    # ambiguous or still multiple; return None to force manual fix
    return None

df_imaging["dataset_slug"] = df_imaging.apply(pick_dataset_slug, axis=1)

print("L3: sample imaging rows with imaging_date_from_sheet and dataset_slug:")
print(
    df_imaging[
        ["Date imaged", "imaging_date_from_sheet", "Data location", "slug_candidates", "dataset_slug"]
    ].head(20)
)
# Out:
# L3: sample imaging rows with imaging_date_from_sheet and dataset_slug:
#    Date imaged imaging_date_from_sheet  \
# 0   2025-11-12                20251112
# 1   2025-11-12                20251112
# 2   2025-11-11                20251111
# 3   2025-11-10                20251110
# 4   2025-11-06                20251106
# 5   2025-11-05                20251105
# 6   2025-11-05                20251105
# 7   2025-10-29                20251029
# 8   2025-10-30                20251030
# 9   2025-10-28                20251028
# 10  2025-10-28                20251028
# 11  2025-10-29                20251029
# 12  2025-10-27                20251027
# 13  2025-10-27                20251027
# 14  2025-10-26                20251026
# 15  2025-10-25                20251025
# 16  2025-10-24                20251024
# 17  2025-10-24                20251024
# 18  2025-10-22                20251022
# 19  2025-10-23                20251023
#
#                                         Data location  \
# 0        X:\abcabc\Korra_Foundation\20251112_mem-mito
# 1      X:\abcabc\Exploratory_fish\20251112_mem-moesin
# 2         X:\abcabc\Aang_Foundation\20251107_mem-mito
# 3     X:\abcabc\Korra_Foundation\20251110_mem-histone
# 4         X:\abcabc\Aang_Foundation\20251106_mem-mito
# 5         X:\abcabc\Aang_Foundation\20251105_mem-mito
# 6        X:\abcabc\Korra_Foundation\20251106_mem-mito
# 7     X:\abcabc\Korra_Foundation\20251029_mem-histone
# 8           X:\abcabc\Aang_Foundation\20251029_peroxi
# 9         X:\abcabc\Aang_Foundation\20251028_mem-mito
# 10      X:\abcabc\Aang_Foundation\20251028_mem-peroxi
# 11     X:\abcabc\Aang_Foundation\20251028_mem-peroxi2
# 12    X:\abcabc\Korra_Foundation\20251027_mem-histone
# 13     X:\abcabc\Aang_Foundation\20251027_mem-histone
# 14             X:\abcabc\Exploratory_fish\20251025_er
# 15  X:\abcabc\Exploratory_fish\20251025_lamellipod...
# 16    X:\abcabc\Korra_Foundation\20251024_mem-histone
# 17        X:\abcabc\Aang_Foundation\20251023_mem-mito
# 18    X:\abcabc\Korra_Foundation\20251022_mem-histone
# 19        X:\abcabc\Aang_Foundation\20251022_mem-mito
#
#                     slug_candidates                   dataset_slug
# 0               [20251112_mem-mito]              20251112_mem-mito
# 1             [20251112_mem-moesin]            20251112_mem-moesin
# 2               [20251107_mem-mito]              20251107_mem-mito
# 3            [20251110_mem-histone]           20251110_mem-histone
# 4               [20251106_mem-mito]              20251106_mem-mito
# 5               [20251105_mem-mito]              20251105_mem-mito
# 6               [20251106_mem-mito]              20251106_mem-mito
# 7            [20251029_mem-histone]           20251029_mem-histone
# 8                 [20251029_peroxi]                20251029_peroxi
# 9               [20251028_mem-mito]              20251028_mem-mito
# 10            [20251028_mem-peroxi]            20251028_mem-peroxi
# 11           [20251028_mem-peroxi2]           20251028_mem-peroxi2
# 12           [20251027_mem-histone]           20251027_mem-histone
# 13           [20251027_mem-histone]           20251027_mem-histone
# 14                    [20251025_er]                    20251025_er
# 15  [20251025_lamellipodia_F-actin]  20251025_lamellipodia_F-actin
# 16           [20251024_mem-histone]           20251024_mem-histone
# 17              [20251023_mem-mito]              20251023_mem-mito
# 18           [20251022_mem-histone]           20251022_mem-histone
# 19              [20251022_mem-mito]              20251022_mem-mito

# %%
# LINKING_V4 — L4: attach dataset_slug + QC on ROI side

# On ROI side, dataset_slug is just experiment_folder (e.g. '20250513_skittlez')
df_roi_paths["dataset_slug"] = df_roi_paths["experiment_folder"]

print("L4: sample ROI rows with dataset_slug + roi_path_date_yyyymmdd:")
print(
    df_roi_paths[
        ["roi_dir", "experiment_folder", "dataset_slug", "roi_path_date_yyyymmdd"]
    ].head(20)
)
# Out:
# L4: sample ROI rows with dataset_slug + roi_path_date_yyyymmdd:
#                                               roi_dir     experiment_folder  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250428_mem_histone
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250428_mem_histone
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
#
#             dataset_slug roi_path_date_yyyymmdd
# 0   20250428_mem_histone               20250428
# 1   20250428_mem_histone               20250428
# 2   20250429_mem_cytosol               20250429
# 3   20250429_mem_cytosol               20250429
# 4   20250429_mem_cytosol               20250429
# 5   20250429_mem_cytosol               20250429
# 6   20250429_mem_cytosol               20250429
# 7   20250429_mem_cytosol               20250429
# 8   20250429_mem_cytosol               20250429
# 9   20250429_mem_cytosol               20250429
# 10     20250513_skittles               20250513
# 11     20250513_skittles               20250513
# 12     20250513_skittles               20250513
# 13     20250513_skittles               20250513
# 14     20250513_skittles               20250513
# 15     20250513_skittles               20250513
# 16     20250513_skittles               20250513
# 17     20250513_skittles               20250513
# 18     20250513_skittles               20250513
# 19     20250513_skittles               20250513

# %%
# LINKING_V4 — L5: merge ROI paths with imaging sheet, and infer for all unmatched

import pandas as pd

im_cols_keep = [
    "dataset_slug",
    "imaging_date_from_sheet",
    "date_mount",
    "Date imaged",
    "Data location",
    "ZF female genotype",
    "ZF male genotype",
]

df_imaging_keys = df_imaging[im_cols_keep].copy()

# QC: ensure ROI side has imaging date parsed
if df_roi_paths["roi_path_date_yyyymmdd"].isna().any():
    bad = df_roi_paths[df_roi_paths["roi_path_date_yyyymmdd"].isna()]
    print("L5: ROI rows with missing roi_path_date_yyyymmdd (should have been filtered in L2b):")
    print(bad[["roi_dir"]].head(20))
    raise ValueError("L5: some ROI rows lack roi_path_date_yyyymmdd; check L2a/L2b.")

# 1) initial merge on (dataset_slug, imaging_date)
df_linked = df_roi_paths.merge(
    df_imaging_keys,
    left_on=["dataset_slug", "roi_path_date_yyyymmdd"],
    right_on=["dataset_slug", "imaging_date_from_sheet"],
    how="left",
    suffixes=("", "_img"),
)

# 2) default link_source = sheet (for rows that matched imaging)
df_linked["link_source"] = "sheet"

print("L5: df_linked rows:", len(df_linked), "unique roi_dir:", df_linked["roi_dir"].nunique())

# 3) find rows with no imaging-sheet match
no_match = df_linked[df_linked["Date imaged"].isna()].copy()
print("L5: ROIs with no imaging-sheet match (before inference):", len(no_match))

if len(no_match):
    cols_show = ["roi_dir", "experiment_folder", "dataset_slug", "roi_path_date_yyyymmdd"]
    print("\nL5: sample unmatched ROIs (before inference):")
    print(no_match[cols_show].head(30))

    summary = (
        no_match.groupby(["experiment_folder", "dataset_slug", "roi_path_date_yyyymmdd"])
                .size()
                .reset_index(name="n_rois")
                .sort_values("n_rois", ascending=False)
    )
    print("\nL5: summary of unmatched experiments (before inference):")
    print(summary.head(50))

    # 4) for ALL unmatched, infer imaging metadata from ROI path
    print("\nL5: inferring imaging metadata for ALL unmatched ROIs from ROI paths...")

    df_linked = df_linked.copy()
    mask_infer = df_linked["Date imaged"].isna()

    # Date imaged = roi_path_date_yyyymmdd
    df_linked.loc[mask_infer, "Date imaged"] = pd.to_datetime(
        df_linked.loc[mask_infer, "roi_path_date_yyyymmdd"], format="%Y%m%d", errors="coerce"
    )

    # date_mount = Date imaged (for now; you can refine later)
    df_linked.loc[mask_infer, "date_mount"] = df_linked.loc[mask_infer, "Date imaged"]

    # imaging_date_from_sheet = roi_path_date_yyyymmdd
    df_linked.loc[mask_infer, "imaging_date_from_sheet"] = df_linked.loc[
        mask_infer, "roi_path_date_yyyymmdd"
    ]

    # mark link_source = inferred
    df_linked.loc[mask_infer, "link_source"] = "inferred"

    print("L5: inference applied to", mask_infer.sum(), "rows.")
else:
    print("L5: no unmatched ROIs; all linked from imaging sheet.")

# 5) sanity: no remaining NaT for Date imaged
remaining_na = df_linked["Date imaged"].isna().sum()
print("L5: remaining rows with Date imaged = NaT:", remaining_na)
if remaining_na:
    raise ValueError("L5: still have rows with Date imaged = NaT after inference; investigate.")

print("\nL5: sample df_linked after sheet+inferred linking:")
print(
    df_linked[
        [
            "roi_dir",
            "dataset_slug",
            "roi_path_date_yyyymmdd",
            "Date imaged",
            "date_mount",
            "link_source",
        ]
    ].head(20)
)
# Out:
# L5: df_linked rows: 1118 unique roi_dir: 975
# L5: ROIs with no imaging-sheet match (before inference): 128
#
# L5: sample unmatched ROIs (before inference):
#                                                roi_dir  \
# 264  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 287  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 288  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 289  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 290  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 291  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 292  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 293  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 294  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 295  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 296  /clusterfs/vast/abcabc/Korra_Foundation/202506...
# 366  /clusterfs/vast/abcabc/Korra_Foundation/202508...
# 367  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 368  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 369  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 370  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 371  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 372  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 373  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 374  /clusterfs/vast/abcabc/Korra_Foundation/202510...
# 482  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 483  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 484  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 485  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 486  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 508  /clusterfs/vast/abcabc/Aang_Foundation/2025072...
# 509  /clusterfs/vast/abcabc/Aang_Foundation/2025080...
# 510  /clusterfs/vast/abcabc/Aang_Foundation/2025080...
# 511  /clusterfs/vast/abcabc/Aang_Foundation/2025080...
# 512  /clusterfs/vast/abcabc/Aang_Foundation/2025080...
#
#                              experiment_folder  \
# 264                           20250620_mitomSG
# 287                          20250625_skittlez
# 288                          20250625_skittlez
# 289                          20250625_skittlez
# 290                          20250625_skittlez
# 291                          20250625_skittlez
# 292                          20250625_skittlez
# 293                          20250625_skittlez
# 294                          20250625_skittlez
# 295                          20250625_skittlez
# 296                          20250625_skittlez
# 366                       20250801_mem-histone
# 367                       20251007_mem-histone
# 368                       20251007_mem-histone
# 369                       20251007_mem-histone
# 370                       20251007_mem-histone
# 371                       20251007_mem-histone
# 372                       20251007_mem-histone
# 373                       20251007_mem-histone
# 374                          20251009_skittlez
# 482  20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 483  20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 484  20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 485  20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 486  20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 508               20250723_er-mSG_mem-mChilada
# 509                  20250805_lifeact_mem-halo
# 510                  20250805_lifeact_mem-halo
# 511                  20250805_lifeact_mem-halo
# 512                  20250805_lifeact_mem-halo
#
#                                   dataset_slug roi_path_date_yyyymmdd
# 264                           20250620_mitomSG               20250620
# 287                          20250625_skittlez               20250625
# 288                          20250625_skittlez               20250625
# 289                          20250625_skittlez               20250625
# 290                          20250625_skittlez               20250625
# 291                          20250625_skittlez               20250625
# 292                          20250625_skittlez               20250625
# 293                          20250625_skittlez               20250625
# 294                          20250625_skittlez               20250625
# 295                          20250625_skittlez               20250625
# 296                          20250625_skittlez               20250625
# 366                       20250801_mem-histone               20250801
# 367                       20251007_mem-histone               20251007
# 368                       20251007_mem-histone               20251007
# 369                       20251007_mem-histone               20251007
# 370                       20251007_mem-histone               20251007
# 371                       20251007_mem-histone               20251007
# 372                       20251007_mem-histone               20251007
# 373                       20251007_mem-histone               20251007
# 374                          20251009_skittlez               20251009
# 482  20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721
# 483  20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721
# 484  20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721
# 485  20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721
# 486  20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721
# 508               20250723_er-mSG_mem-mChilada               20250723
# 509                  20250805_lifeact_mem-halo               20250805
# 510                  20250805_lifeact_mem-halo               20250805
# 511                  20250805_lifeact_mem-halo               20250805
# 512                  20250805_lifeact_mem-halo               20250805
#
# L5: summary of unmatched experiments (before inference):
#                             experiment_folder  \
# 7                           20251002_mem_mito
# 21                          20251107_mem-mito
# 9                        20251006_mem_histone
# 1                           20250625_skittlez
# 14                       20251021_mem-mito_v2
# 10                       20251007_mem-histone
# 8                         20251003_mem_tester
# 11                       20251007_mem_histone
# 6                        20250903_lifeact-mSG
# 5                   20250805_lifeact_mem-halo
# 2   20250721_72hpf_mrna_mSG_organelle_LLS-SIM
# 17                       20251028_mem-peroxi2
# 12                          20251009_mem-mito
# 15                          20251022_mem-mito
# 16                          20251023_mem-mito
# 19                            20251029_peroxi
# 18                            20251028_peroxi
# 4                        20250801_mem-histone
# 3                20250723_er-mSG_mem-mChilada
# 13                          20251009_skittlez
# 20                   20251107_mem-kinectocore
# 0                            20250620_mitomSG
#
#                                  dataset_slug roi_path_date_yyyymmdd  n_rois
# 7                           20251002_mem_mito               20251002      24
# 21                          20251107_mem-mito               20251107      13
# 9                        20251006_mem_histone               20251006      11
# 1                           20250625_skittlez               20250625      10
# 14                       20251021_mem-mito_v2               20251021       7
# 10                       20251007_mem-histone               20251007       7
# 8                         20251003_mem_tester               20251003       7
# 11                       20251007_mem_histone               20251007       7
# 6                        20250903_lifeact-mSG               20250903       6
# 5                   20250805_lifeact_mem-halo               20250805       5
# 2   20250721_72hpf_mrna_mSG_organelle_LLS-SIM               20250721       5
# 17                       20251028_mem-peroxi2               20251028       5
# 12                          20251009_mem-mito               20251009       4
# 15                          20251022_mem-mito               20251022       4
# 16                          20251023_mem-mito               20251023       3
# 19                            20251029_peroxi               20251029       3
# 18                            20251028_peroxi               20251028       2
# 4                        20250801_mem-histone               20250801       1
# 3                20250723_er-mSG_mem-mChilada               20250723       1
# 13                          20251009_skittlez               20251009       1
# 20                   20251107_mem-kinectocore               20251107       1
# 0                            20250620_mitomSG               20250620       1
#
# L5: inferring imaging metadata for ALL unmatched ROIs from ROI paths...
# L5: inference applied to 128 rows.
# L5: remaining rows with Date imaged = NaT: 0
#
# L5: sample df_linked after sheet+inferred linking:
#                                               roi_dir          dataset_slug  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250428_mem_histone
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250428_mem_histone
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...  20250429_mem_cytosol
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...     20250513_skittles
#
#    roi_path_date_yyyymmdd Date imaged date_mount link_source
# 0                20250428  2025-04-28 2025-04-28       sheet
# 1                20250428  2025-04-28 2025-04-28       sheet
# 2                20250429  2025-04-29 2025-04-29       sheet
# 3                20250429  2025-04-29 2025-04-29       sheet
# 4                20250429  2025-04-29 2025-04-29       sheet
# 5                20250429  2025-04-29 2025-04-29       sheet
# 6                20250429  2025-04-29 2025-04-29       sheet
# 7                20250429  2025-04-29 2025-04-29       sheet
# 8                20250429  2025-04-29 2025-04-29       sheet
# 9                20250429  2025-04-29 2025-04-29       sheet
# 10               20250513  2025-05-13 2025-05-13       sheet
# 11               20250513  2025-05-13 2025-05-13       sheet
# 12               20250513  2025-05-13 2025-05-13       sheet
# 13               20250513  2025-05-13 2025-05-13       sheet
# 14               20250513  2025-05-13 2025-05-13       sheet
# 15               20250513  2025-05-13 2025-05-13       sheet
# 16               20250513  2025-05-13 2025-05-13       sheet
# 17               20250513  2025-05-13 2025-05-13       sheet
# 18               20250513  2025-05-13 2025-05-13       sheet
# 19               20250513  2025-05-13 2025-05-13       sheet

# %%
# LINKING_V4 — L6: infer mount_id from fish_id, then derive plate/slot/ROI indices

import pandas as pd

df_linked = df_linked.copy()

# 1) plate_date from date_mount (sheet or inferred)
if df_linked["date_mount"].isna().any():
    bad = df_linked[df_linked["date_mount"].isna()]
    print("L6: rows with missing date_mount after imaging/inference:")
    print(bad[["roi_dir", "experiment_folder", "dataset_slug", "Date imaged", "link_source"]].head(30))

    out_bad_mount = WORKING / "linking_v4_missing_date_mount_rows.csv"
    bad[["roi_dir", "experiment_folder", "dataset_slug",
         "date_mount", "Date imaged", "Data location", "link_source"]].to_csv(
        out_bad_mount, index=False
    )
    print("\nL6: wrote rows with missing date_mount to:", out_bad_mount)
    raise ValueError("L6: date_mount is NaT for some rows; fix/improve upstream inference.")

df_linked["plate_date"] = pd.to_datetime(
    df_linked["date_mount"], errors="raise"
).dt.strftime("%Y%m%d")

# fish_id must exist
if "fish_id" not in df_linked.columns:
    raise KeyError("L6: df_linked missing 'fish_id' column; update L2c to compute it.")


def infer_mount_id_per_group(fish_ids: pd.Series) -> pd.Series:
    """
    Given fish_id values for a (plate_date, experiment_folder),
    assign mount IDs so that each mount has up to 6 unique fish_id entries.

    Steps:
      - Get sorted unique fish_id
      - Map each fish_id to an index 0..N-1
      - mount_id_inferred = idx // 6 + 1
    """
    uniques = sorted(fish_ids.unique())
    idx_map = {f: i for i, f in enumerate(uniques)}
    idx = fish_ids.map(idx_map)
    return (idx // 6) + 1


# 2) infer mount_id_inferred for each (plate_date, experiment_folder)
df_linked["mount_id_inferred"] = (
    df_linked
    .sort_values(["plate_date", "experiment_folder", "fish_id"])
    .groupby(["plate_date", "experiment_folder"])["fish_id"]
    .transform(infer_mount_id_per_group)
)

df_linked["mount_id_source"] = "inferred"

# 3) plate_key = (plate_date, experiment_folder, mount_id_inferred)
df_linked["plate_key"] = (
    df_linked["plate_date"].astype(str)
    + "::" + df_linked["experiment_folder"].astype(str)
    + "::" + df_linked["mount_id_inferred"].astype(int).astype(str)
)

# global plate_id_filled (int)
df_linked["plate_id_filled"] = pd.factorize(df_linked["plate_key"])[0] + 1

# 4) slot_id_filled: per plate, index fish_id
df_linked["slot_id_filled"] = (
    df_linked
    .sort_values(["plate_id_filled", "fish_id"])
    .groupby("plate_id_filled")["fish_id"]
    .transform(lambda s: pd.factorize(s, sort=True)[0] + 1)
)

# 5) roi_index_within_slot: per (plate_id, slot_id), index roi_folder
df_linked["roi_index_within_slot"] = (
    df_linked
    .sort_values(["plate_id_filled", "slot_id_filled", "roi_folder"])
    .groupby(["plate_id_filled", "slot_id_filled"])["roi_folder"]
    .cumcount() + 1
)

# 6) QC: unique fish_id per inferred plate must be <= 6
fish_counts = (
    df_linked
    .groupby(["plate_date", "experiment_folder", "mount_id_inferred", "plate_id_filled"])["fish_id"]
    .nunique()
    .reset_index(name="n_fish")
)

bad_plates = fish_counts[fish_counts["n_fish"] > 6]
print("L6: inferred plates with >6 fish_id (should be 0):", len(bad_plates))
if len(bad_plates):
    print(bad_plates.head(20))
    out_bad_plates = WORKING / "linking_v4_bad_plates_n_fish_gt6_INFERRED.csv"
    bad_plates.to_csv(out_bad_plates, index=False)
    print("\nL6: wrote bad inferred plates summary to:", out_bad_plates)
    raise ValueError("L6: found inferred plates with more than 6 fish; check inference logic.")

print("\nL6: sample plate/slot/ROI hierarchy (inferred mount IDs):")
print(
    df_linked[
        [
            "roi_dir",
            "plate_date",
            "experiment_folder",
            "mount_id_inferred",
            "plate_id_filled",
            "fish_id",
            "slot_id_filled",
            "roi_folder",
            "roi_index_within_slot",
            "Date imaged",
            "date_mount",
            "link_source",
        ]
    ].head(30)
)
# Out:
# L6: inferred plates with >6 fish_id (should be 0): 0
#
# L6: sample plate/slot/ROI hierarchy (inferred mount IDs):
#                                               roi_dir plate_date  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250428
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250428
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...   20250429
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 15  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 16  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 17  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 18  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 19  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 20  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 21  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 22  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 23  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 24  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 25  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 26  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 27  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 28  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
# 29  /clusterfs/vast/abcabc/Korra_Foundation/202505...   20250513
#
#        experiment_folder  mount_id_inferred  plate_id_filled  \
# 0   20250428_mem_histone                  1                1
# 1   20250428_mem_histone                  1                1
# 2   20250429_mem_cytosol                  1                2
# 3   20250429_mem_cytosol                  1                2
# 4   20250429_mem_cytosol                  1                2
# 5   20250429_mem_cytosol                  1                2
# 6   20250429_mem_cytosol                  1                2
# 7   20250429_mem_cytosol                  1                2
# 8   20250429_mem_cytosol                  1                2
# 9   20250429_mem_cytosol                  1                2
# 10     20250513_skittles                  1                3
# 11     20250513_skittles                  1                3
# 12     20250513_skittles                  1                3
# 13     20250513_skittles                  1                3
# 14     20250513_skittles                  1                3
# 15     20250513_skittles                  1                3
# 16     20250513_skittles                  1                3
# 17     20250513_skittles                  1                3
# 18     20250513_skittles                  1                3
# 19     20250513_skittles                  1                3
# 20     20250513_skittles                  1                3
# 21     20250513_skittles                  1                3
# 22     20250513_skittles                  1                3
# 23     20250513_skittles                  1                3
# 24     20250513_skittles                  1                3
# 25     20250513_skittles                  2                4
# 26     20250513_skittles                  2                4
# 27     20250513_skittles                  2                4
# 28     20250513_skittles                  2                4
# 29     20250513_skittles                  2                4
#
#                  fish_id  slot_id_filled            roi_folder  \
# 0            fish1_72hpf               1             roi1_tail
# 1            fish1_72hpf               1  roi2_hindbrain_spine
# 2            fish1_24hpf               1                  roi1
# 3            fish1_24hpf               1             roi1_test
# 4            fish2_48hpf               2                  roi1
# 5   fish3_mem-halo_24hpf               3                  roi1
# 6   fish3_mem-halo_24hpf               3                  roi2
# 7   fish4_mem-halo_48hpf               4                  roi1
# 8   fish4_mem-halo_48hpf               4                  roi2
# 9   fish4_mem-halo_48hpf               4                  roi3
# 10                 fish1               1                  roi1
# 11                 fish1               1                  roi2
# 12                 fish1               1                roi2_2
# 13                fish10               2                  roi1
# 14                fish11               3                  roi1
# 15                fish11               3             roi1_test
# 16                fish12               4                  roi1
# 17                fish12               4                  roi2
# 18                fish12               4                  roi3
# 19                fish13               5                  roi1
# 20                fish13               5                  roi2
# 21                fish13               5                  roi3
# 22                fish13               5                  roi4
# 23                fish14               6            roi1_brain
# 24                fish14               6          roi2_tailbud
# 25                fish15               1                  roi1
# 26                fish15               1                  roi2
# 27                fish15               1                  roi3
# 28                fish15               1                  roi4
# 29                fish16               2            roi1_brain
#
#     roi_index_within_slot Date imaged date_mount link_source
# 0                       1  2025-04-28 2025-04-28       sheet
# 1                       2  2025-04-28 2025-04-28       sheet
# 2                       1  2025-04-29 2025-04-29       sheet
# 3                       2  2025-04-29 2025-04-29       sheet
# 4                       1  2025-04-29 2025-04-29       sheet
# 5                       1  2025-04-29 2025-04-29       sheet
# 6                       2  2025-04-29 2025-04-29       sheet
# 7                       1  2025-04-29 2025-04-29       sheet
# 8                       2  2025-04-29 2025-04-29       sheet
# 9                       3  2025-04-29 2025-04-29       sheet
# 10                      1  2025-05-13 2025-05-13       sheet
# 11                      2  2025-05-13 2025-05-13       sheet
# 12                      3  2025-05-13 2025-05-13       sheet
# 13                      1  2025-05-13 2025-05-13       sheet
# 14                      1  2025-05-13 2025-05-13       sheet
# 15                      2  2025-05-13 2025-05-13       sheet
# 16                      1  2025-05-13 2025-05-13       sheet
# 17                      2  2025-05-13 2025-05-13       sheet
# 18                      3  2025-05-13 2025-05-13       sheet
# 19                      1  2025-05-13 2025-05-13       sheet
# 20                      2  2025-05-13 2025-05-13       sheet
# 21                      3  2025-05-13 2025-05-13       sheet
# 22                      4  2025-05-13 2025-05-13       sheet
# 23                      1  2025-05-13 2025-05-13       sheet
# 24                      2  2025-05-13 2025-05-13       sheet
# 25                      1  2025-05-13 2025-05-13       sheet
# 26                      2  2025-05-13 2025-05-13       sheet
# 27                      3  2025-05-13 2025-05-13       sheet
# 28                      4  2025-05-13 2025-05-13       sheet
# 29                      1  2025-05-13 2025-05-13       sheet

# %%
# QC — 20250606 fish_id per inferred mount
mask_0606 = df_linked["plate_date"] == "20250606"
fish_counts_0606 = (
    df_linked[mask_0606]
    .groupby(["experiment_folder", "mount_id_inferred"])["fish_id"]
    .nunique()
    .reset_index(name="n_fish")
    .sort_values(["experiment_folder", "mount_id_inferred"])
)
print(fish_counts_0606)
# Out:
#    experiment_folder  mount_id_inferred  n_fish
# 0  20250606_skittlez                  1       6
# 1  20250606_skittlez                  2       6
# 2  20250606_skittlez                  3       2

# %%
# LINKING_V4 — L7: construct bruker_roi_id

def make_bruker_roi_id(row):
    # bruker ID = YYYYMMDD-plateN-slotN-roiN
    date = row["plate_date"]
    plate = row["plate_id_filled"]
    slot  = row["slot_id_filled"]
    idx   = row["roi_index_within_slot"]
    return f"{date}-plate{plate}-slot{slot}-roi{idx}"

df_linked = df_linked.copy()
df_linked["bruker_roi_id"] = df_linked.apply(make_bruker_roi_id, axis=1)

print("L7: sample bruker_roi_id values:")
print(
    df_linked[
        ["roi_dir", "bruker_roi_id", "plate_date",
         "plate_id_filled", "slot_id_filled", "roi_index_within_slot"]
    ].head(15)
)
# Out:
# L7: sample bruker_roi_id values:
#                                               roi_dir  \
# 0   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 1   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 2   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 3   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 4   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 5   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 6   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 7   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 8   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 9   /clusterfs/vast/abcabc/Korra_Foundation/202504...
# 10  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 11  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 12  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 13  /clusterfs/vast/abcabc/Korra_Foundation/202505...
# 14  /clusterfs/vast/abcabc/Korra_Foundation/202505...
#
#                  bruker_roi_id plate_date  plate_id_filled  slot_id_filled  \
# 0   20250428-plate1-slot1-roi1   20250428                1               1
# 1   20250428-plate1-slot1-roi2   20250428                1               1
# 2   20250429-plate2-slot1-roi1   20250429                2               1
# 3   20250429-plate2-slot1-roi2   20250429                2               1
# 4   20250429-plate2-slot2-roi1   20250429                2               2
# 5   20250429-plate2-slot3-roi1   20250429                2               3
# 6   20250429-plate2-slot3-roi2   20250429                2               3
# 7   20250429-plate2-slot4-roi1   20250429                2               4
# 8   20250429-plate2-slot4-roi2   20250429                2               4
# 9   20250429-plate2-slot4-roi3   20250429                2               4
# 10  20250513-plate3-slot1-roi1   20250513                3               1
# 11  20250513-plate3-slot1-roi2   20250513                3               1
# 12  20250513-plate3-slot1-roi3   20250513                3               1
# 13  20250513-plate3-slot2-roi1   20250513                3               2
# 14  20250513-plate3-slot3-roi1   20250513                3               3
#
#     roi_index_within_slot
# 0                       1
# 1                       2
# 2                       1
# 3                       2
# 4                       1
# 5                       1
# 6                       2
# 7                       1
# 8                       2
# 9                       3
# 10                      1
# 11                      2
# 12                      3
# 13                      1
# 14                      1

# %%
# LINKING_V4 — L8: write final structural CSV

out_path = WORKING / "output_from_linking.csv"
df_linked.to_csv(out_path, index=False)

print("L8: wrote linking output to:", out_path)
print("L8: df_linked shape:", df_linked.shape)
print("L8: unique roi_dir:", df_linked["roi_dir"].nunique())
print("L8: link_source breakdown:")
print(df_linked["link_source"].value_counts())
# Out:
# L8: wrote linking output to: /Users/davekokel/Projects/carp_v2/seed_kits/legacy_wrangling_v2/working/output_from_linking.csv
# L8: df_linked shape: (1118, 28)
# L8: unique roi_dir: 975
# L8: link_source breakdown:
# link_source
# sheet       990
# inferred    128
# Name: count, dtype: int64

# %%
# QC-A — Compare experiment_folder-derived date vs imaging sheet date_mount

import re

def extract_date_prefix(exp_folder):
    if exp_folder is None:
        return None
    m = re.match(r"^(\d{8})_", str(exp_folder))
    return m.group(1) if m else None

df_qc_date = df_linked.copy()
df_qc_date["date_mount_derived"] = df_qc_date["experiment_folder"].apply(extract_date_prefix)
df_qc_date["date_mount_sheet"]   = df_qc_date["date_mount"].dt.strftime("%Y%m%d")

df_qc_date["date_match"] = df_qc_date["date_mount_derived"] == df_qc_date["date_mount_sheet"]

n_total = len(df_qc_date)
n_match = df_qc_date["date_match"].sum()
n_mismatch = n_total - n_match

print("QC-A: total rows:", n_total)
print("QC-A: matches:", n_match)
print("QC-A: mismatches:", n_mismatch)

if n_mismatch > 0:
    print("\nQC-A sample mismatches:")
    print(
        df_qc_date.loc[~df_qc_date["date_match"],
                       ["roi_dir","experiment_folder","date_mount_derived","date_mount_sheet"]]
        .head(20)
    )
# Out:
# QC-A: total rows: 1118
# QC-A: matches: 1047
# QC-A: mismatches: 71
#
# QC-A sample mismatches:
#                                                roi_dir     experiment_folder  \
# 395  /clusterfs/vast/abcabc/Korra_Foundation/202510...  20251015_mem-histone
# 397  /clusterfs/vast/abcabc/Korra_Foundation/202510...  20251015_mem-histone
# 399  /clusterfs/vast/abcabc/Korra_Foundation/202510...  20251015_mem-histone
# 401  /clusterfs/vast/abcabc/Korra_Foundation/202510...  20251015_mem-histone
# 403  /clusterfs/vast/abcabc/Korra_Foundation/202510...  20251015_mem-histone
# 727  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 728  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 729  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 730  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 731  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 732  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 733  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 734  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 735  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 736  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 737  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 738  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 739  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 740  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
# 741  /clusterfs/vast/abcabc/Aang_Foundation/2025091...     20250917_mem-mito
#
#     date_mount_derived date_mount_sheet
# 395           20251015         20251014
# 397           20251015         20251014
# 399           20251015         20251014
# 401           20251015         20251014
# 403           20251015         20251014
# 727           20250917         20250916
# 728           20250917         20250916
# 729           20250917         20250916
# 730           20250917         20250916
# 731           20250917         20250916
# 732           20250917         20250916
# 733           20250917         20250916
# 734           20250917         20250916
# 735           20250917         20250916
# 736           20250917         20250916
# 737           20250917         20250916
# 738           20250917         20250916
# 739           20250917         20250916
# 740           20250917         20250916
# 741           20250917         20250916

# %%
# QC-B — Per imaging_date (YYYYMMDD) summary: n_plates, n_fish, n_rois, n_tiffs
# Updated: now uses marker='o' in all plots for clarity.

import pandas as pd
import matplotlib.pyplot as plt

df_qc = df_linked.copy()
df_qc["imaging_date"] = pd.to_datetime(df_qc["Date imaged"]).dt.strftime("%Y%m%d")

summary = (
    df_qc.groupby("imaging_date")
    .agg(
        n_plates = ("plate_id_filled", "nunique"),
        n_fish   = ("fish_id", "nunique"),
        n_rois   = ("roi_dir", "nunique"),
        n_tiffs  = ("roi_tiffs", "sum"),
    )
    .reset_index()
    .sort_values("imaging_date")
)

print("QC-B summary head:")
print(summary.head(20))

plt.figure(figsize=(28, 12))

plt.subplot(4,1,1)
plt.plot(summary["imaging_date"], summary["n_plates"], marker='o')
plt.title("Plates per Imaging Date")
plt.xticks(rotation=90)

plt.subplot(4,1,2)
plt.plot(summary["imaging_date"], summary["n_fish"], marker='o')
plt.title("Fish per Imaging Date")
plt.xticks(rotation=90)

plt.subplot(4,1,3)
plt.plot(summary["imaging_date"], summary["n_rois"], marker='o')
plt.title("ROIs per Imaging Date")
plt.xticks(rotation=90)

plt.subplot(4,1,4)
plt.plot(summary["imaging_date"], summary["n_tiffs"], marker='o')
plt.title("TIFF count per Imaging Date")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
# Out:
# QC-B summary head:
#    imaging_date  n_plates  n_fish  n_rois  n_tiffs
# 0      20250428         1       1       2    12966
# 1      20250429         1       4       8    29229
# 2      20250513         3      16      44     2087
# 3      20250520         1       3       4    19140
# 4      20250521         1       3       5      165
# 5      20250522         2       9      19     1506
# 6      20250523         1       5       5    57000
# 7      20250528         2       3       5    20316
# 8      20250529         3      15      22     2064
# 9      20250530         1       3       3    19186
# 10     20250602         1       1       1    15812
# 11     20250603         3      16      18     2010
# 12     20250605         3      14      21     1644
# 13     20250606         3      14      23     1464
# 14     20250609         2       9       9    29928
# 15     20250612         2       8      10     1590
# 16     20250613         2      12      12     1434
# 17     20250616         1       6       6    20052
# 18     20250618         2      12      23     1488
# 19     20250619         1       5       8      612
